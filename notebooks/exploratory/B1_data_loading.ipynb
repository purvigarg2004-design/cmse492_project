# %% [markdown]
# # B1. Data Acquisition and Loading
# #### Data source
# For this project I am using the “Weather Prediction” dataset from Kaggle.That dataset was created from the European Climate Assessment & Dataset (ECA&D) project.
# Original citation: Klein Tank, A.M.G. and Coauthors, 2002. Daily dataset of 20th-century surface air temperature and precipitation series for the European Climate Assessment. International Journal of Climatology, 22, 1441–1453.
# Original data and metadata are available at ecad.eu. The Kaggle version already collects daily data from 18 European stations (2000–2010) and converts some units (temperature to °C, wind to m/s, precipitation to cm), so it’s good for ML teaching.
# I will load the CSV from data/raw/ and keep only a small sample in data/processed/ for testing.

# %%
import os
import sys
sys.path.append("/Users/purvigarg/Downloads/CMSE492/cmse492_project")
from src.preprocessing.features import load_raw_weather
import pandas as pd

DATA_PATH = "/Users/purvigarg/Downloads/CMSE492/cmse492_project/data/raw/weather_prediction_dataset.csv"
data = load_raw_weather(DATA_PATH)
data = pd.read_csv(DATA_PATH)

# basic info
print("Shape:", data.shape)          # rows, columns
# Out:
# Shape: (3654, 165)

# %%
print("\nDtypes:")
# Out:
# Dtypes:

# %%
print(data.dtypes.head(40))          # show first 40 dtypes
# Out:
# DATE                           int64
# MONTH                          int64
# BASEL_cloud_cover              int64
# BASEL_humidity               float64
# BASEL_pressure               float64
# BASEL_global_radiation       float64
# BASEL_precipitation          float64
# BASEL_sunshine               float64
# BASEL_temp_mean              float64
# BASEL_temp_min               float64
# BASEL_temp_max               float64
# BUDAPEST_cloud_cover           int64
# BUDAPEST_humidity            float64
# BUDAPEST_pressure            float64
# BUDAPEST_global_radiation    float64
# BUDAPEST_precipitation       float64
# BUDAPEST_sunshine            float64
# BUDAPEST_temp_mean           float64
# BUDAPEST_temp_max            float64
# DE_BILT_cloud_cover            int64
# DE_BILT_wind_speed           float64
# DE_BILT_wind_gust            float64
# DE_BILT_humidity             float64
# DE_BILT_pressure             float64
# DE_BILT_global_radiation     float64
# ...

# %%
print("\nFirst 5 rows:")
display(data.head())
# Out:
# First 5 rows:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0  20000101      1                  8            0.89          1.0286
# 1  20000102      1                  8            0.87          1.0318
# 2  20000103      1                  5            0.81          1.0314
# 3  20000104      1                  7            0.79          1.0262
# 4  20000105      1                  5            0.90          1.0246
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 0                    0.20                 0.03             0.0
# 1                    0.25                 0.00             0.0
# 2                    0.50                 0.00             3.7
# 3                    0.63                 0.35             6.9
# 4                    0.51                 0.07             3.7
#
#    BASEL_temp_mean  BASEL_temp_min  ...  STOCKHOLM_temp_min  \
# 0              2.9             1.6  ...                -9.3
# ...

# %%
print("\nDataset Info:")
print(data.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3654 entries, 0 to 3653
# Columns: 165 entries, DATE to TOURS_temp_max
# dtypes: float64(150), int64(15)
# memory usage: 4.6 MB
# None

# %% [markdown]
# For this part, I successfully loaded the Kaggle “Weather Prediction” dataset (originally from the ECA&D project) from data/raw/weather_prediction.csv and confirmed that it contains a few thousand daily weather records with many columns for different European cities. I checked the shape, data types, and the first few rows, so now I know what variables are available (pressure, temperatures, humidity, cloud cover, sunshine, radiation, precipitation, etc.) and that the file is readable in my environment. Because the dataset is not very large, I decided I don’t need to create a separate sample file right now; I can work directly with the full dataset in the next steps. This completes the “Data Acquisition and Loading” part, and I can now move on to selecting the columns I actually need for the Basel rain prediction task.
